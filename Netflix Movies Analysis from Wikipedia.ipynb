# %%
# import required libraries

import pandas as pd
import re
import seaborn as sns

# %%
# https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2015-2017)
# https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2018)
# https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2019)
# https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2020)
# https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2021)
# https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2022)

movies_2015_2017: list = pd.read_html("https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2015-2017)")
# movies_2018: list = pd.read_html("https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2018)")
# movies_2019: list = pd.read_html("https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2019)")
# movies_2020: list = pd.read_html("https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2020)")
# movies_2021: list = pd.read_html("https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2021)")
# movies_2022: list = pd.read_html("https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2022)")

#read_html returns a list of dataframes
    
#count number of items in list
print("Number of items in list is: {}".format(len(movies_2015_2017)))
# Out:
# Number of items in list is: 4

# %%
# Get feature_films (first item)
movies_2015_2017[0]
# Out:
#                                             Title                       Genre  \
# 0                             Beasts of No Nation                   War drama
# 1                                The Ridiculous 6                     Western
# 2                           Pee-wee's Big Holiday                   Adventure
# 3                          Special Correspondents                      Satire
# 4                                     The Do-Over               Action comedy
# 5                      The Fundamentals of Caring                Comedy drama
# 6                                   Brahman Naman                      Comedy
# 7                                         Rebirth                    Thriller
# 8                                        Tallulah                Comedy drama
# 9                                            XOXO                       Drama
# 10                                            ARQ  Science fiction / Thriller
# ...

# %%
# get documentaries (second item)
movies_2015_2017[1]
# Out:
#                                                 Title            Premiere  \
# 0                                          My Own Man       March 6, 2015
# 1    The Other One: The Long Strange Trip of Bob Weir        May 22, 2015
# 2                                    Hot Girls Wanted        May 29, 2015
# 3                         What Happened, Miss Simone?       June 26, 2015
# 4                                                 Tig       July 17, 2015
# 5                 Keith Richards: Under the Influence  September 18, 2015
# 6         Winter on Fire: Ukraine's Fight for Freedom     October 9, 2015
# 7                           My Beautiful Broken Brain      March 18, 2016
# 8                                     Team Foxcatcher      April 29, 2016
# 9                    Tony Robbins: I Am Not Your Guru       July 15, 2016
# 10                           I'll Sleep When I'm Dead     August 19, 2016
# 11                                           Extremis  September 13, 2016
# ...

# %%
# get specials (third item)
movies_2015_2017[2]
# Out:
#                                                Title                  Genre  \
# 0                            A Very Murray Christmas       Comedy / Musical
# 1             Justin Timberlake + The Tennessee Kids           Concert film
# 2  13th: A Conversation with Oprah Winfrey & Ava ...  Aftershow / Interview
# 3  Michael Bolton's Big, Sexy Valentine's Day Spe...           Variety show
# 4                                        Rodney King           One-man show
# 5         Barbra: The Music, The Mem'ries, The Magic           Concert film
#
#             Premiere     Runtime Language
# 0   December 4, 2015      56 min  English
# 1   October 12, 2016  1 h 30 min  English
# 2   January 26, 2017      36 min  English
# 3   February 7, 2017      54 min  English
# 4     April 28, 2017      52 min  English
# 5  November 22, 2017  1 h 48 min  English

# %%
# https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2015-2017)
# https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2018)
# https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2019)
# https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2020)
# https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2021)
# https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2022)

BASE_URL: str = "https://en.wikipedia.org/wiki/List_of_Netflix_original_films_({year})"
YEARS: list = ["2015-2017", "2018", "2019", "2020", "2021", "2022"]

for value in years:
    full_url: str = base_url.format(year=value)
    print(full_url)

# %%
# movies: list = pd.read_html("https://en.wikipedia.org/wiki/List_of_Netflix_original_films_(2015-2017)")

# Create an empty dataframe to hold all the feature films.
feature_films = pd.DataFrame()

# Create an empty dataframe to hold all the documentaries.
documentaries = pd.DataFrame()

BASE_URL: str = "https://en.wikipedia.org/wiki/List_of_Netflix_original_films_({year})"
YEARS: list = ["2015-2017", "2018", "2019", "2020", "2021", "2022"] 
    
# 1st iteration --> value = "2015-2017"    
# 2nd iteration --> value = "2018"   
# 3rd iteration --> value = "2019"   
# 4th iteration --> value = "2020"   
# 5th iteration --> value = "2021"   
# 6th iteration --> value = "2022"   
    
    
for value in YEARS:
    full_url: str = BASE_URL.format(year=value)
    netflix_movies: list = pd.read_html(full_url)
    feature_films = pd.concat([feature_films, netflix_movies[0]])
    documentaries = pd.concat([documentaries, netflix_movies[1]])

# %%
#Get the head for the feature_films(first elements in the dataframe)
feature_films.head(10)
# Out:
#                         Title          Genre           Premiere     Runtime  \
# 0         Beasts of No Nation      War drama   October 16, 2015  2 h 17 min
# 1            The Ridiculous 6        Western  December 11, 2015         2 h
# 2       Pee-wee's Big Holiday      Adventure     March 18, 2016  1 h 30 min
# 3      Special Correspondents         Satire     April 29, 2016  1 h 41 min
# 4                 The Do-Over  Action comedy       May 27, 2016  1 h 48 min
# 5  The Fundamentals of Caring   Comedy drama      June 24, 2016  1 h 37 min
# 6               Brahman Naman         Comedy       July 7, 2016  1 h 35 min
# 7                     Rebirth       Thriller      July 15, 2016  1 h 40 min
# 8                    Tallulah   Comedy drama      July 29, 2016  1 h 51 min
# 9                        XOXO          Drama    August 26, 2016  1 h 32 min
#
#   Language
# 0  English
# 1  English
# 2  English
# 3  English
# 4  English
# 5  English
# 6  English
# 7  English
# 8  English
# ...

# %%
#Get the tail for the feature_films(last elements in the dataframe)
feature_films.tail(10)
# Out:
#                                              Title  \
# 162                               The Marriage App
# 163                 Guillermo del Toro's Pinocchio
# 164                             I Believe in Santa
# 165                                      The Big 4
# 166  Bardo, False Chronicle of a Handful of Truths
# 167                                 Private Lesson
# 168                       A Not So Merry Christmas
# 169              Glass Onion: A Knives Out Mystery
# 170                    A Night at the Kindergarten
# 171                                    White Noise
#
#                                  Genre           Premiere     Runtime  \
# 162                              Drama   December 7, 2022  1 h 41 min
# 163  Stop motion fantasy musical drama   December 9, 2022  1 h 56 min
# 164                    Romantic comedy  December 14, 2022  1 h 30 min
# 165                      Action comedy  December 15, 2022  2 h 21 min
# ...

# %%
#Get the head for the documentaries(first elements in the dataframe)
documentaries.head(10)
# Out:
#                                               Title            Premiere  \
# 0                                        My Own Man       March 6, 2015
# 1  The Other One: The Long Strange Trip of Bob Weir        May 22, 2015
# 2                                  Hot Girls Wanted        May 29, 2015
# 3                       What Happened, Miss Simone?       June 26, 2015
# 4                                               Tig       July 17, 2015
# 5               Keith Richards: Under the Influence  September 18, 2015
# 6       Winter on Fire: Ukraine's Fight for Freedom     October 9, 2015
# 7                         My Beautiful Broken Brain      March 18, 2016
# 8                                   Team Foxcatcher      April 29, 2016
# 9                  Tony Robbins: I Am Not Your Guru       July 15, 2016
#
#       Runtime   Language
# 0  1 h 21 min    English
# 1  1 h 23 min    English
# 2  1 h 24 min    English
# 3  1 h 24 min    English
# 4  1 h 20 min    English
# ...

# %%
#Get the tail for the documentaries(last elements in the dataframe)
documentaries.tail(10)
# Out:
#                                    Title           Premiere     Runtime  \
# 49                  I Am Vanessa Guillen  November 17, 2022  1 h 36 min
# 50        Ghislaine Maxwell: Filthy Rich  November 25, 2022  1 h 41 min
# 51                 The Last Dolphin King  November 25, 2022  1 h 34 min
# 52                Take Your Pills: Xanax  November 30, 2022  1 h 30 min
# 53                    The Masked Scammer   December 1, 2022  1 h 30 min
# 54                                 "Sr."   December 2, 2022  1 h 30 min
# 55  In Broad Daylight: The Narvarte Case   December 8, 2022  1 h 48 min
# 56               The Elephant Whisperers   December 8, 2022      41 min
# 57                       Kangaroo Valley  December 14, 2022  1 h 16 min
# 58     The Volcano: Rescue from Whakaari  December 16, 2022  1 h 38 min
#
#    Language
# 49  English
# 50  English
# 51  Spanish
# 52  English
# 53  English
# 54  English
# 55  Spanish
# 56    Tamil
# 57  English
# 58  English

# %%
print("The shape of feature films is {}".format(feature_films.shape))
print("The shape of documentaries is {}".format(documentaries.shape))
# Out:
# The shape of feature films is (657, 5)
# The shape of documentaries is (250, 4)

# %%
feature_films
# Out:
#                                  Title            Genre           Premiere  \
# 0                  Beasts of No Nation        War drama   October 16, 2015
# 1                     The Ridiculous 6          Western  December 11, 2015
# 2                Pee-wee's Big Holiday        Adventure     March 18, 2016
# 3               Special Correspondents           Satire     April 29, 2016
# 4                          The Do-Over    Action comedy       May 27, 2016
# ..                                 ...              ...                ...
# 167                     Private Lesson  Romantic comedy  December 16, 2022
# 168           A Not So Merry Christmas           Comedy  December 20, 2022
# 169  Glass Onion: A Knives Out Mystery   Murder mystery  December 23, 2022
# 170        A Night at the Kindergarten     Black comedy  December 28, 2022
# 171                        White Noise     Black comedy  December 30, 2022
#
#         Runtime Language
# 0    2 h 17 min  English
# ...

# %%
# Reindex the feature_films dataframe
feature_films.index = range(len(feature_films.index))
feature_films
# Out:
#                                  Title            Genre           Premiere  \
# 0                  Beasts of No Nation        War drama   October 16, 2015
# 1                     The Ridiculous 6          Western  December 11, 2015
# 2                Pee-wee's Big Holiday        Adventure     March 18, 2016
# 3               Special Correspondents           Satire     April 29, 2016
# 4                          The Do-Over    Action comedy       May 27, 2016
# ..                                 ...              ...                ...
# 652                     Private Lesson  Romantic comedy  December 16, 2022
# 653           A Not So Merry Christmas           Comedy  December 20, 2022
# 654  Glass Onion: A Knives Out Mystery   Murder mystery  December 23, 2022
# 655        A Night at the Kindergarten     Black comedy  December 28, 2022
# 656                        White Noise     Black comedy  December 30, 2022
#
#         Runtime Language
# 0    2 h 17 min  English
# ...

# %%
# Reindex the documentaries dataframe
documentaries.index = range(len(documentaries.index))
documentaries
# Out:
#                                                 Title           Premiere  \
# 0                                          My Own Man      March 6, 2015
# 1    The Other One: The Long Strange Trip of Bob Weir       May 22, 2015
# 2                                    Hot Girls Wanted       May 29, 2015
# 3                         What Happened, Miss Simone?      June 26, 2015
# 4                                                 Tig      July 17, 2015
# ..                                                ...                ...
# 245                                             "Sr."   December 2, 2022
# 246              In Broad Daylight: The Narvarte Case   December 8, 2022
# 247                           The Elephant Whisperers   December 8, 2022
# 248                                   Kangaroo Valley  December 14, 2022
# 249                 The Volcano: Rescue from Whakaari  December 16, 2022
#
#         Runtime Language
# 0    1 h 21 min  English
# 1    1 h 23 min  English
# ...

# %%
# get info about the dataframe
feature_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 657 entries, 0 to 656
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     657 non-null    object
#  1   Genre     657 non-null    object
#  2   Premiere  657 non-null    object
#  3   Runtime   657 non-null    object
#  4   Language  657 non-null    object
# dtypes: object(5)
# memory usage: 25.8+ KB

# %%
# Convert the Column "Premiere" into a datetime object to make it easier to work with
feature_films["Premiere"] = pd.to_datetime(feature_films["Premiere"], infer_datetime_format=True)

# %%
feature_films
# Out:
#                                  Title            Genre   Premiere  \
# 0                  Beasts of No Nation        War drama 2015-10-16
# 1                     The Ridiculous 6          Western 2015-12-11
# 2                Pee-wee's Big Holiday        Adventure 2016-03-18
# 3               Special Correspondents           Satire 2016-04-29
# 4                          The Do-Over    Action comedy 2016-05-27
# ..                                 ...              ...        ...
# 652                     Private Lesson  Romantic comedy 2022-12-16
# 653           A Not So Merry Christmas           Comedy 2022-12-20
# 654  Glass Onion: A Knives Out Mystery   Murder mystery 2022-12-23
# 655        A Night at the Kindergarten     Black comedy 2022-12-28
# 656                        White Noise     Black comedy 2022-12-30
#
#         Runtime Language
# 0    2 h 17 min  English
# 1           2 h  English
# 2    1 h 30 min  English
# 3    1 h 41 min  English
# 4    1 h 48 min  English
# ...

# %%
# get info about the dataframe
feature_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 657 entries, 0 to 656
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     657 non-null    object
#  1   Genre     657 non-null    object
#  2   Premiere  657 non-null    datetime64[ns]
#  3   Runtime   657 non-null    object
#  4   Language  657 non-null    object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 25.8+ KB
